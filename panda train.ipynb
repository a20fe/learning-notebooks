# %%
import pandas as pd
import numpy as np 
dict={'name':['ahmed' ,' ali' , 'nohaa' ,'hossam' ,'asmaa' ,'aya' ,'sabra'],
         'marks':[50,35,80,99,46,67,87] , 'gender':['male' ,'male' ,'female' ,'male' ,'female','female','female']}
df=pd.DataFrame(dict)
df
# Out:
#      name  marks  gender
# 0   ahmed     50    male
# 1     ali     35    male
# 2   nohaa     80  female
# 3  hossam     99    male
# 4   asmaa     46  female
# 5     aya     67  female
# 6   sabra     87  female

# %%
df
# Out:
#      name  marks  gender
# 0   ahmed     50    male
# 1     ali     35    male
# 2   nohaa     80  female
# 3  hossam     99    male
# 4   asmaa     46  female
# 5     aya     67  female
# 6   sabra     87  female

# %%
df.head(3)
# Out:
#     name  marks  gender
# 0  ahmed     50    male
# 1    ali     35    male
# 2  nohaa     80  female

# %%
df.tail(3)
# Out:
#     name  marks  gender
# 4  asmaa     46  female
# 5    aya     67  female
# 6  sabra     87  female

# %%
df.shape
# Out:
# (7, 3)

# %%
df.value_counts()
# Out:
# name    marks  gender
#  ali    35     male      1
# ahmed   50     male      1
# asmaa   46     female    1
# aya     67     female    1
# hossam  99     male      1
# nohaa   80     female    1
# sabra   87     female    1
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    7 non-null      object
#  1   marks   7 non-null      int64
#  2   gender  7 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 296.0+ bytes

# %%
df.isnull().sum(axis=0)
# Out:
# name      0
# marks     0
# gender    0
# dtype: int64

# %%
df.describe()
# Out:
#            marks
# count   7.000000
# mean   66.285714
# std    23.605891
# min    35.000000
# 25%    48.000000
# 50%    67.000000
# 75%    83.500000
# max    99.000000

# %%
df.describe(include='all')
# Out:
#          name      marks  gender
# count       7   7.000000       7
# unique      7        NaN       2
# top     ahmed        NaN  female
# freq        1        NaN       4
# mean      NaN  66.285714     NaN
# std       NaN  23.605891     NaN
# min       NaN  35.000000     NaN
# 25%       NaN  48.000000     NaN
# 50%       NaN  67.000000     NaN
# 75%       NaN  83.500000     NaN
# max       NaN  99.000000     NaN

# %%
df['gender'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
len(df[df['marks']>=90])
# Out:
# 1

# %%
df['marks'].between(90,100)
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6    False
# Name: marks, dtype: bool

# %%
df['marks'].mean()
# Out:
# 66.28571428571429

# %%
def grade(x):
    if x>=50 :
        print('pass')
    else :
        print('fail')
df['marks'].apply(grade)
# Out:
# pass
# fail
# pass
# pass
# fail
# pass
# pass
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None
# 5    None
# 6    None
# Name: marks, dtype: object

# %%
df['half grade'] =df['marks'].apply(lambda x: x/2)

# %%
df
# Out:
#      name  marks  gender  half grade
# 0   ahmed     50    male        25.0
# 1     ali     35    male        17.5
# 2   nohaa     80  female        40.0
# 3  hossam     99    male        49.5
# 4   asmaa     46  female        23.0
# 5     aya     67  female        33.5
# 6   sabra     87  female        43.5

# %%
df['male'] = df['gender'].map({'male':'posetive' ,'female':'negative'})

# %%
df
# Out:
#      name  marks  gender  half grade      male
# 0   ahmed     50    male        25.0  posetive
# 1     ali     35    male        17.5  posetive
# 2   nohaa     80  female        40.0  negative
# 3  hossam     99    male        49.5  posetive
# 4   asmaa     46  female        23.0  negative
# 5     aya     67  female        33.5  negative
# 6   sabra     87  female        43.5  negative

# %%
df.drop('male', axis=1 , inplace=True)

# %%
df
# Out:
#      name  marks  gender  half grade
# 0   ahmed     50    male        25.0
# 1     ali     35    male        17.5
# 2   nohaa     80  female        40.0
# 3  hossam     99    male        49.5
# 4   asmaa     46  female        23.0
# 5     aya     67  female        33.5
# 6   sabra     87  female        43.5

# %%
df.columns
# Out:
# Index(['name', 'marks', 'gender', 'half grade'], dtype='object')

# %%
df.sort_values(by='marks' , ascending=False)
# Out:
#      name  marks  gender  half grade
# 3  hossam     99    male        49.5
# 6   sabra     87  female        43.5
# 2   nohaa     80  female        40.0
# 5     aya     67  female        33.5
# 0   ahmed     50    male        25.0
# 4   asmaa     46  female        23.0
# 1     ali     35    male        17.5

# %%
df[df['gender']=='female'][['name','marks']]
# Out:
#     name  marks
# 2  nohaa     80
# 4  asmaa     46
# 5    aya     67
# 6  sabra     87

# %%
dict1={'name':['ahmed' ,' ali' , 'nohaa' ,'hossam' ,'asmaa' ,'aya' ,'sabra'],
         'marks':[50,np.nan,80,99,46,np.nan,87] , 'gender':['male' ,'male' ,'female' ,'male' ,'female','female','female'] ,
      'email':['elshawkey@gmail.com','ahmed@mail.com','ali@gmail.com','hossam@yahoo.com','ali@yahoo.com','asmaa@gmail.com' ,'ahmed@mail.com']}
df1=pd.DataFrame(dict1)
df1
# Out:
#      name  marks  gender                email
# 0   ahmed   50.0    male  elshawkey@gmail.com
# 1     ali    NaN    male       ahmed@mail.com
# 2   nohaa   80.0  female        ali@gmail.com
# 3  hossam   99.0    male     hossam@yahoo.com
# 4   asmaa   46.0  female        ali@yahoo.com
# 5     aya    NaN  female      asmaa@gmail.com
# 6   sabra   87.0  female       ahmed@mail.com

# %%
df1.head(3)
# Out:
#     name  marks  gender                email
# 0  ahmed   50.0    male  elshawkey@gmail.com
# 1    ali    NaN    male       ahmed@mail.com
# 2  nohaa   80.0  female        ali@gmail.com

# %%
df1.head(-2)
# Out:
#      name  marks  gender                email
# 0   ahmed   50.0    male  elshawkey@gmail.com
# 1     ali    NaN    male       ahmed@mail.com
# 2   nohaa   80.0  female        ali@gmail.com
# 3  hossam   99.0    male     hossam@yahoo.com
# 4   asmaa   46.0  female        ali@yahoo.com

# %%
df1.head(-3)
# Out:
#      name  marks  gender                email
# 0   ahmed   50.0    male  elshawkey@gmail.com
# 1     ali    NaN    male       ahmed@mail.com
# 2   nohaa   80.0  female        ali@gmail.com
# 3  hossam   99.0    male     hossam@yahoo.com

# %%
df1.shape
# Out:
# (7, 4)

# %%
df1['marks'].shape
# Out:
# (7,)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    7 non-null      object
#  1   marks   5 non-null      float64
#  2   gender  7 non-null      object
#  3   email   7 non-null      object
# dtypes: float64(1), object(3)
# memory usage: 352.0+ bytes

# %%
df1.isnull().sum()
# Out:
# name      0
# marks     2
# gender    0
# email     0
# dtype: int64

# %%
df1.describe(include='all')
# Out:
#          name      marks  gender           email
# count       7   5.000000       7               7
# unique      7        NaN       2               6
# top     ahmed        NaN  female  ahmed@mail.com
# freq        1        NaN       4               2
# mean      NaN  72.400000     NaN             NaN
# std       NaN  23.330238     NaN             NaN
# min       NaN  46.000000     NaN             NaN
# 25%       NaN  50.000000     NaN             NaN
# 50%       NaN  80.000000     NaN             NaN
# 75%       NaN  87.000000     NaN             NaN
# max       NaN  99.000000     NaN             NaN

# %%
df1['gender'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
 df1['gender'].value_counts()
# Out:
# gender
# female    4
# male      3
# Name: count, dtype: int64

# %% [markdown]
# df1.dropna()

# %%
df1
# Out:
#      name  marks  gender                email
# 0   ahmed   50.0    male  elshawkey@gmail.com
# 1     ali    NaN    male       ahmed@mail.com
# 2   nohaa   80.0  female        ali@gmail.com
# 3  hossam   99.0    male     hossam@yahoo.com
# 4   asmaa   46.0  female        ali@yahoo.com
# 5     aya    NaN  female      asmaa@gmail.com
# 6   sabra   87.0  female       ahmed@mail.com

# %%
df1.dropna(how='any')
# Out:
#      name  marks  gender                email
# 0   ahmed   50.0    male  elshawkey@gmail.com
# 2   nohaa   80.0  female        ali@gmail.com
# 3  hossam   99.0    male     hossam@yahoo.com
# 4   asmaa   46.0  female        ali@yahoo.com
# 6   sabra   87.0  female       ahmed@mail.com

# %%
df1.fillna(999)
# Out:
#      name  marks  gender                email
# 0   ahmed   50.0    male  elshawkey@gmail.com
# 1     ali  999.0    male       ahmed@mail.com
# 2   nohaa   80.0  female        ali@gmail.com
# 3  hossam   99.0    male     hossam@yahoo.com
# 4   asmaa   46.0  female        ali@yahoo.com
# 5     aya  999.0  female      asmaa@gmail.com
# 6   sabra   87.0  female       ahmed@mail.com

# %%
df1['marks'].fillna(df1['marks'].mean() , inplace =True)

# %%
df1
# Out:
#      name  marks  gender                email
# 0   ahmed   50.0    male  elshawkey@gmail.com
# 1     ali   72.4    male       ahmed@mail.com
# 2   nohaa   80.0  female        ali@gmail.com
# 3  hossam   99.0    male     hossam@yahoo.com
# 4   asmaa   46.0  female        ali@yahoo.com
# 5     aya   72.4  female      asmaa@gmail.com
# 6   sabra   87.0  female       ahmed@mail.com

# %%
df1[df1['marks'].between(80,90)]
# Out:
#     name  marks  gender           email
# 2  nohaa   80.0  female   ali@gmail.com
# 6  sabra   87.0  female  ahmed@mail.com

# %%
filt=(df1['marks'] >= 80) & (df1['marks']<=90)
df1[filt]
# Out:
#     name  marks  gender           email
# 2  nohaa   80.0  female   ali@gmail.com
# 6  sabra   87.0  female  ahmed@mail.com

# %%
df1[df1['marks'].min()==df1['marks']]['name']
# Out:
# 4    asmaa
# Name: name, dtype: object

# %%
df1.nlargest(5,'marks') [['name','marks']]
# Out:
#      name  marks
# 3  hossam   99.0
# 6   sabra   87.0
# 2   nohaa   80.0
# 1     ali   72.4
# 5     aya   72.4

# %%
df1.sort_values(by='marks')
# Out:
#      name  marks  gender                email
# 4   asmaa   46.0  female        ali@yahoo.com
# 0   ahmed   50.0    male  elshawkey@gmail.com
# 1     ali   72.4    male       ahmed@mail.com
# 5     aya   72.4  female      asmaa@gmail.com
# 2   nohaa   80.0  female        ali@gmail.com
# 6   sabra   87.0  female       ahmed@mail.com
# 3  hossam   99.0    male     hossam@yahoo.com

# %%
df1['marks'].mean()
# Out:
# 72.39999999999999

# %%
df1['marks'].agg(['mean','min','max'])
# Out:
# mean    72.4
# min     46.0
# max     99.0
# Name: marks, dtype: float64

# %% [markdown]
# df1['half marks']=df['marks'].apply(lambda x:x\2)

# %%
df1['half marks'] = df1['marks'].apply(lambda x: x/2)

# %%
df1
# Out:
#      name  marks  gender                email  half marks
# 0   ahmed   50.0    male  elshawkey@gmail.com        25.0
# 1     ali   72.4    male       ahmed@mail.com        36.2
# 2   nohaa   80.0  female        ali@gmail.com        40.0
# 3  hossam   99.0    male     hossam@yahoo.com        49.5
# 4   asmaa   46.0  female        ali@yahoo.com        23.0
# 5     aya   72.4  female      asmaa@gmail.com        36.2
# 6   sabra   87.0  female       ahmed@mail.com        43.5

# %%
df1['gender'].map({'male':1 ,'female':0})
# Out:
# 0    1
# 1    1
# 2    0
# 3    1
# 4    0
# 5    0
# 6    0
# Name: gender, dtype: int64

# %%
df1.drop('half marks' , axis=1 , inplace=True)

# %%
df1
# Out:
#      name  marks  gender                email
# 0   ahmed   50.0    male  elshawkey@gmail.com
# 1     ali   72.4    male       ahmed@mail.com
# 2   nohaa   80.0  female        ali@gmail.com
# 3  hossam   99.0    male     hossam@yahoo.com
# 4   asmaa   46.0  female        ali@yahoo.com
# 5     aya   72.4  female      asmaa@gmail.com
# 6   sabra   87.0  female       ahmed@mail.com

# %%
filt=df1['gender'].isin(['female'])
df1[filt][['name','marks']]
# Out:
#     name  marks
# 2  nohaa   80.0
# 4  asmaa   46.0
# 5    aya   72.4
# 6  sabra   87.0

# %%
df1.rename(columns={'marks':'final marks'} , inplace = True)

# %%
df1
# Out:
#      name  final marks  gender                email
# 0   ahmed         50.0    male  elshawkey@gmail.com
# 1     ali         72.4    male       ahmed@mail.com
# 2   nohaa         80.0  female        ali@gmail.com
# 3  hossam         99.0    male     hossam@yahoo.com
# 4   asmaa         46.0  female        ali@yahoo.com
# 5     aya         72.4  female      asmaa@gmail.com
# 6   sabra         87.0  female       ahmed@mail.com

# %%
df3 =pd.concat([df , df1],ignore_index=True)

# %%
df3.loc[:,'marks':'gender']
# Out:
#     marks  gender
# 0    50.0    male
# 1    35.0    male
# 2    80.0  female
# 3    99.0    male
# 4    46.0  female
# 5    67.0  female
# 6    87.0  female
# 7     NaN    male
# 8     NaN    male
# 9     NaN  female
# 10    NaN    male
# 11    NaN  female
# 12    NaN  female
# 13    NaN  female

# %%
df3.iloc[0:3,:]
df1.columns
# Out:
# Index(['name', 'final marks', 'gender', 'email'], dtype='object')

# %%
df1['name']+ ' ' + df1['final marks'].apply(str)
# Out:
# 0     ahmed 50.0
# 1       ali 72.4
# 2     nohaa 80.0
# 3    hossam 99.0
# 4     asmaa 46.0
# 5       aya 72.4
# 6     sabra 87.0
# dtype: object

# %%
type(df1.groupby('gender')['final marks'].mean().to_frame())
# Out:
# pandas.core.frame.DataFrame

# %%
df1.columns
# Out:
# Index(['name', 'final marks', 'gender', 'email'], dtype='object')

# %%
list=[]
for mail in df1['email']:
   list.append( mail.split('@')[1])
list
# Out:
# ['gmail.com',
#  'mail.com',
#  'gmail.com',
#  'yahoo.com',
#  'yahoo.com',
#  'gmail.com',
#  'mail.com']

# %%
df['temp'] = df1['email'].apply(lambda x: x.split('@')[1])

# %%
df
# Out:
#      name  marks  gender  half grade       temp
# 0   ahmed     50    male        25.0  gmail.com
# 1     ali     35    male        17.5   mail.com
# 2   nohaa     80  female        40.0  gmail.com
# 3  hossam     99    male        49.5  yahoo.com
# 4   asmaa     46  female        23.0  yahoo.com
# 5     aya     67  female        33.5  gmail.com
# 6   sabra     87  female        43.5   mail.com

# %%
df1.iloc[: ,1]
# Out:
# 0    50.0
# 1    72.4
# 2    80.0
# 3    99.0
# 4    46.0
# 5    72.4
# 6    87.0
# Name: final marks, dtype: float64

# %%
df1
# Out:
#      name  final marks  gender                email
# 0   ahmed         50.0    male  elshawkey@gmail.com
# 1     ali         72.4    male       ahmed@mail.com
# 2   nohaa         80.0  female        ali@gmail.com
# 3  hossam         99.0    male     hossam@yahoo.com
# 4   asmaa         46.0  female        ali@yahoo.com
# 5     aya         72.4  female      asmaa@gmail.com
# 6   sabra         87.0  female       ahmed@mail.com

# %%
df1.set_index('name')
# Out:
#         final marks  gender                email
# name
# ahmed          50.0    male  elshawkey@gmail.com
#  ali           72.4    male       ahmed@mail.com
# nohaa          80.0  female        ali@gmail.com
# hossam         99.0    male     hossam@yahoo.com
# asmaa          46.0  female        ali@yahoo.com
# aya            72.4  female      asmaa@gmail.com
# sabra          87.0  female       ahmed@mail.com

# %%
pd.set_option('display.max_columns' ,15)

# %%
df3
# Out:
#       name  marks  gender  half grade  final marks                email
# 0    ahmed   50.0    male        25.0          NaN                  NaN
# 1      ali   35.0    male        17.5          NaN                  NaN
# 2    nohaa   80.0  female        40.0          NaN                  NaN
# 3   hossam   99.0    male        49.5          NaN                  NaN
# 4    asmaa   46.0  female        23.0          NaN                  NaN
# 5      aya   67.0  female        33.5          NaN                  NaN
# 6    sabra   87.0  female        43.5          NaN                  NaN
# 7    ahmed    NaN    male         NaN         50.0  elshawkey@gmail.com
# 8      ali    NaN    male         NaN         72.4       ahmed@mail.com
# 9    nohaa    NaN  female         NaN         80.0        ali@gmail.com
# 10  hossam    NaN    male         NaN         99.0     hossam@yahoo.com
# 11   asmaa    NaN  female         NaN         46.0        ali@yahoo.com
# ...

# %%
df3.set_index('name')
# Out:
#         marks  gender  half grade  final marks                email
# name
# ahmed    50.0    male        25.0          NaN                  NaN
#  ali     35.0    male        17.5          NaN                  NaN
# nohaa    80.0  female        40.0          NaN                  NaN
# hossam   99.0    male        49.5          NaN                  NaN
# asmaa    46.0  female        23.0          NaN                  NaN
# aya      67.0  female        33.5          NaN                  NaN
# sabra    87.0  female        43.5          NaN                  NaN
# ahmed     NaN    male         NaN         50.0  elshawkey@gmail.com
#  ali      NaN    male         NaN         72.4       ahmed@mail.com
# nohaa     NaN  female         NaN         80.0        ali@gmail.com
# hossam    NaN    male         NaN         99.0     hossam@yahoo.com
# asmaa     NaN  female         NaN         46.0        ali@yahoo.com
# aya       NaN  female         NaN         72.4      asmaa@gmail.com
# ...

# %%
df.reset_index
# Out:
# <bound method DataFrame.reset_index of      name  marks  gender  half grade       temp
# 0   ahmed     50    male        25.0  gmail.com
# 1     ali     35    male        17.5   mail.com
# 2   nohaa     80  female        40.0  gmail.com
# 3  hossam     99    male        49.5  yahoo.com
# 4   asmaa     46  female        23.0  yahoo.com
# 5     aya     67  female        33.5  gmail.com
# 6   sabra     87  female        43.5   mail.com>

# %%
df.sort_index
# Out:
# <bound method DataFrame.sort_index of      name  marks  gender  half grade       temp
# 0   ahmed     50    male        25.0  gmail.com
# 1     ali     35    male        17.5   mail.com
# 2   nohaa     80  female        40.0  gmail.com
# 3  hossam     99    male        49.5  yahoo.com
# 4   asmaa     46  female        23.0  yahoo.com
# 5     aya     67  female        33.5  gmail.com
# 6   sabra     87  female        43.5   mail.com>

# %%
df.set_index('name' ,inplace = True)

# %%
df
# Out:
#         marks  gender  half grade       temp
# name
# ahmed      50    male        25.0  gmail.com
#  ali       35    male        17.5   mail.com
# nohaa      80  female        40.0  gmail.com
# hossam     99    male        49.5  yahoo.com
# asmaa      46  female        23.0  yahoo.com
# aya        67  female        33.5  gmail.com
# sabra      87  female        43.5   mail.com

# %%
df.sort_index(inplace = True)

# %%
df
# Out:
#         marks  gender  half grade       temp
# name
#  ali       35    male        17.5   mail.com
# ahmed      50    male        25.0  gmail.com
# asmaa      46  female        23.0  yahoo.com
# aya        67  female        33.5  gmail.com
# hossam     99    male        49.5  yahoo.com
# nohaa      80  female        40.0  gmail.com
# sabra      87  female        43.5   mail.com

# %%
df.reset_index
# Out:
# <bound method DataFrame.reset_index of         marks  gender  half grade       temp
# name
#  ali       35    male        17.5   mail.com
# ahmed      50    male        25.0  gmail.com
# asmaa      46  female        23.0  yahoo.com
# aya        67  female        33.5  gmail.com
# hossam     99    male        49.5  yahoo.com
# nohaa      80  female        40.0  gmail.com
# sabra      87  female        43.5   mail.com>

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#      name  marks  gender  half grade       temp
# 0     ali     35    male        17.5   mail.com
# 1   ahmed     50    male        25.0  gmail.com
# 2   asmaa     46  female        23.0  yahoo.com
# 3     aya     67  female        33.5  gmail.com
# 4  hossam     99    male        49.5  yahoo.com
# 5   nohaa     80  female        40.0  gmail.com
# 6   sabra     87  female        43.5   mail.com

# %%
df3
# Out:
#       name  marks  gender  half grade  final marks                email
# 0    ahmed   50.0    male        25.0          NaN                  NaN
# 1      ali   35.0    male        17.5          NaN                  NaN
# 2    nohaa   80.0  female        40.0          NaN                  NaN
# 3   hossam   99.0    male        49.5          NaN                  NaN
# 4    asmaa   46.0  female        23.0          NaN                  NaN
# 5      aya   67.0  female        33.5          NaN                  NaN
# 6    sabra   87.0  female        43.5          NaN                  NaN
# 7    ahmed    NaN    male         NaN         50.0  elshawkey@gmail.com
# 8      ali    NaN    male         NaN         72.4       ahmed@mail.com
# 9    nohaa    NaN  female         NaN         80.0        ali@gmail.com
# 10  hossam    NaN    male         NaN         99.0     hossam@yahoo.com
# 11   asmaa    NaN  female         NaN         46.0        ali@yahoo.com
# ...

# %%
filt=df3['gender'].isin(['female'])
df3[filt]
df3[-filt]
# Out:
#       name  marks gender  half grade  final marks                email
# 0    ahmed   50.0   male        25.0          NaN                  NaN
# 1      ali   35.0   male        17.5          NaN                  NaN
# 3   hossam   99.0   male        49.5          NaN                  NaN
# 7    ahmed    NaN   male         NaN         50.0  elshawkey@gmail.com
# 8      ali    NaN   male         NaN         72.4       ahmed@mail.com
# 10  hossam    NaN   male         NaN         99.0     hossam@yahoo.com

# %%
filt=df3['email'].str.contains('gmail' , na=False)
df3[filt]
# Out:
#      name  marks  gender  half grade  final marks                email
# 7   ahmed    NaN    male         NaN         50.0  elshawkey@gmail.com
# 9   nohaa    NaN  female         NaN         80.0        ali@gmail.com
# 12    aya    NaN  female         NaN         72.4      asmaa@gmail.com

# %%
df3.columns = df3.columns.str.replace(' ' ,'_' )

# %%
df3
# Out:
#       name  marks  gender  half_grade  final_marks                email
# 0    ahmed   50.0    male        25.0          NaN                  NaN
# 1      ali   35.0    male        17.5          NaN                  NaN
# 2    nohaa   80.0  female        40.0          NaN                  NaN
# 3   hossam   99.0    male        49.5          NaN                  NaN
# 4    asmaa   46.0  female        23.0          NaN                  NaN
# 5      aya   67.0  female        33.5          NaN                  NaN
# 6    sabra   87.0  female        43.5          NaN                  NaN
# 7    ahmed    NaN    male         NaN         50.0  elshawkey@gmail.com
# 8      ali    NaN    male         NaN         72.4       ahmed@mail.com
# 9    nohaa    NaN  female         NaN         80.0        ali@gmail.com
# 10  hossam    NaN    male         NaN         99.0     hossam@yahoo.com
# 11   asmaa    NaN  female         NaN         46.0        ali@yahoo.com
# ...

# %%
df3.rename(columns= {'final_marks':'marks'} , inplace= True)

# %%
df3.rename(columns={'email':'mail'} , inplace =True)

# %%
df3
# Out:
#       name  marks  gender  half_grade  marks                 mail
# 0    ahmed   50.0    male        25.0    NaN                  NaN
# 1      ali   35.0    male        17.5    NaN                  NaN
# 2    nohaa   80.0  female        40.0    NaN                  NaN
# 3   hossam   99.0    male        49.5    NaN                  NaN
# 4    asmaa   46.0  female        23.0    NaN                  NaN
# 5      aya   67.0  female        33.5    NaN                  NaN
# 6    sabra   87.0  female        43.5    NaN                  NaN
# 7    ahmed    NaN    male         NaN   50.0  elshawkey@gmail.com
# 8      ali    NaN    male         NaN   72.4       ahmed@mail.com
# 9    nohaa    NaN  female         NaN   80.0        ali@gmail.com
# 10  hossam    NaN    male         NaN   99.0     hossam@yahoo.com
# 11   asmaa    NaN  female         NaN   46.0        ali@yahoo.com
# 12     aya    NaN  female         NaN   72.4      asmaa@gmail.com
# ...

# %%
df3['mail']=df3['mail'].str.upper()

# %%
df3
# Out:
#       name  marks  gender  half_grade  marks                 mail
# 0    ahmed   50.0    male        25.0    NaN                  NaN
# 1      ali   35.0    male        17.5    NaN                  NaN
# 2    nohaa   80.0  female        40.0    NaN                  NaN
# 3   hossam   99.0    male        49.5    NaN                  NaN
# 4    asmaa   46.0  female        23.0    NaN                  NaN
# 5      aya   67.0  female        33.5    NaN                  NaN
# 6    sabra   87.0  female        43.5    NaN                  NaN
# 7    ahmed    NaN    male         NaN   50.0  ELSHAWKEY@GMAIL.COM
# 8      ali    NaN    male         NaN   72.4       AHMED@MAIL.COM
# 9    nohaa    NaN  female         NaN   80.0        ALI@GMAIL.COM
# 10  hossam    NaN    male         NaN   99.0     HOSSAM@YAHOO.COM
# 11   asmaa    NaN  female         NaN   46.0        ALI@YAHOO.COM
# 12     aya    NaN  female         NaN   72.4      ASMAA@GMAIL.COM
# ...

# %%
df3['mail'] = df3['mail'].str.lower()

# %%
df3
# Out:
#       name  marks  gender  half_grade  marks                 mail
# 0    ahmed   50.0    male        25.0    NaN                  NaN
# 1      ali   35.0    male        17.5    NaN                  NaN
# 2    nohaa   80.0  female        40.0    NaN                  NaN
# 3   hossam   99.0    male        49.5    NaN                  NaN
# 4    asmaa   46.0  female        23.0    NaN                  NaN
# 5      aya   67.0  female        33.5    NaN                  NaN
# 6    sabra   87.0  female        43.5    NaN                  NaN
# 7    ahmed    NaN    male         NaN   50.0  elshawkey@gmail.com
# 8      ali    NaN    male         NaN   72.4       ahmed@mail.com
# 9    nohaa    NaN  female         NaN   80.0        ali@gmail.com
# 10  hossam    NaN    male         NaN   99.0     hossam@yahoo.com
# 11   asmaa    NaN  female         NaN   46.0        ali@yahoo.com
# 12     aya    NaN  female         NaN   72.4      asmaa@gmail.com
# ...
